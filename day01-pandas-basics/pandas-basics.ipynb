# %%
#Creating Simple Data Framework
import pandas as pd
data={
    "Name" : ["Alok", "Ram", "Hari"],
    "Age" : [25, 30 , 35],
    "city" : ["Itahari", "Dharan", "KTM"],
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Name  Age     city
# 0  Alok   25  Itahari
# 1   Ram   30   Dharan
# 2  Hari   35      KTM
